# %% [markdown]
# # Lab #2
# This lab is the first step to get farmilliar with some common Machine Learning libraries, named ***Pandas*** and ***Matlotlib***.
#
# *   **Deadline: 23:59, 27/02/2023**

# %% [markdown]
# #0. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/???'
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-8-32a2fe44b05e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#       3 get_ipython().run_line_magic('cd', "'/content/gdrive/MyDrive/???'")
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.8/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     121       'TBE_EPHEM_CREDS_ADDR'] if ephemeral else _os.environ['TBE_CREDS_ADDR']
#     122   if ephemeral:
# ...

# %% [markdown]
# #1. Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #2. Load dataset
#
# *   Load dataset (named ***shopping-data.csv***) using ***read_csv*** from pandas
# *   Then, display 10 last examples

# %%
df = pd.read_csv('shopping-data.csv')
print(df)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# #3. Show statistics of the given dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %% [markdown]
# #4. Sort dataset by ***Age***

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.sort_values(by=["Age"], ascending=False)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 70           71    Male   70                  49                      55
# 60           61    Male   70                  46                      56
# 57           58    Male   69                  44                      46
# 90           91  Female   68                  59                      55
# 67           68  Female   68                  48                      48
# ..          ...     ...  ...                 ...                     ...
# 0             1    Male   19                  15                      39
# 33           34    Male   18                  33                      92
# 65           66    Male   18                  48                      59
# 91           92    Male   18                  59                      41
# 114         115  Female   18                  65                      48
#
# [200 rows x 5 columns]

# %% [markdown]
# #5. Group dataset by ***Gender*** and ***Age***

# %%
df.groupby(by=['Genre']).size()
df.groupby(by=['Age']).size()
# Out:
# Age
# 18     4
# 19     8
# 20     5
# 21     5
# 22     3
# 23     6
# 24     4
# 25     3
# 26     2
# 27     6
# 28     4
# 29     5
# 30     7
# 31     8
# 32    11
# 33     3
# 34     5
# 35     9
# 36     6
# 37     3
# 38     6
# 39     3
# 40     6
# 41     2
# 42     2
# 43     3
# 44     2
# 45     3
# 46     3
# 47     6
# 48     5
# 49     7
# 50     5
# 51     2
# 52     2
# 53     2
# 54     4
# 55     1
# 56     1
# 57     2
# 58     2
# 59     4
# 60     3
# 63     2
# 64     1
# 65     2
# 66     2
# 67     4
# 68     3
# 69     1
# 70     2
# dtype: int64

# %% [markdown]
# #6. Use scatter plot to represent the relationship between ***Age*** and ***Annual Income***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
plt.plot(df["Age"], df["Genre"], color='green', linestyle='dashed', linewidth = 3, 
marker='o', markerfacecolor='blue', markersize=12)
plt.xlabel('Age')
plt.ylabel('Genre')
# Out:
# Text(0, 0.5, 'Genre')

# %% [markdown]
# #7. Use histogram plot to represent the distribution of ***Age***

# %%
arr=df["Age"].unique()
rs=[0,0,0,0]
step=(df["Age"].max()-df["Age"].min())/4
map={}
activities = []
count=df["Age"].min()
while(count<70):
  end=count+step
  activities.append(str(count)+"-"+str(end))
  count=end 
for tmp in arr:
  for i in range(len(activities)):
    print
    if(tmp>df["Age"].min()&tmp<df["Age"].min()+step*(i+1)):
      rs[i]+=1
colors = ['r', 'y', 'g', 'b']
plt.pie(rs, labels = activities, colors=colors, 
startangle=90, shadow = True, explode = (0, 0, 0.1, 0), 
radius = 1.2, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1da27e6a60>,
# ...
#  [Text(-0.9333809511662426, 0.9333809511662429, '18-31.0'),
#   Text(-0.933380951166243, -0.9333809511662426, '31.0-44.0'),
#   Text(1.0040916292848974, -1.0040916292848978, '44.0-57.0'),
#   Text(0.933380951166243, 0.9333809511662425, '57.0-70.0')],
#  [Text(-0.5091168824543142, 0.5091168824543142, '25.0%'),
#   Text(-0.5091168824543143, -0.5091168824543142, '25.0%'),
#   Text(0.5798275605729688, -0.579827560572969, '25.0%'),
#   Text(0.5091168824543143, 0.5091168824543141, '25.0%')])

# %% [markdown]
# #8. Finally,
# Save a copy in your Github. Remember renaming the notebook.
